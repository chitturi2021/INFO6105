# %% [markdown]
# #  US Election 2020 Tweets --- Sentiment Analysis

# %%
#conda install -c conda-forge wordcloud
#conda install -c conda-forge textblob
#conda install geopandas

# %%
#imports
# %matplotlib inline

import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.probability import FreqDist


nltk.download('stopwords')
nltk.download('punkt')
nltk.download('vader_lexicon')

import matplotlib.pyplot as plt
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
#import geopandas as gpd
#from shapely.geometry import Point

import string
import re
from textblob import TextBlob #sentimate analysis
from textblob import Word
from nltk.probability import FreqDist

from scipy import stats
import seaborn as sns; sns.set()

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from collections import Counter
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\chitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\chitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\chitt\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import os
for dirname, _, filenames in os.walk(os.curdir):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# .\archive.zip
# .\final-proj1 (4).ipynb
# .\hashtag_donaldtrump.csv
# .\hashtag_donaldtrump1.xlsx
# .\hashtag_joebiden.csv
# .\US Election 2020 Tweets --- Sentiment Analysis-Copy1.ipynb
# .\US Election 2020 Tweets --- Sentiment Analysis-Copy2.ipynb
# .\US Election 2020 Tweets --- Sentiment Analysis.ipynb
# .\.ipynb_checkpoints\final-proj1 (4)-checkpoint.ipynb
# .\.ipynb_checkpoints\US Election 2020 Tweets --- Sentiment Analysis-checkpoint.ipynb
# .\.ipynb_checkpoints\US Election 2020 Tweets --- Sentiment Analysis-Copy1-checkpoint.ipynb
# .\.ipynb_checkpoints\US Election 2020 Tweets --- Sentiment Analysis-Copy2-checkpoint.ipynb

# %%
#trump_data = pd.read_csv("../input/us-election-2020-tweets/hashtag_donaldtrump.csv",lineterminator='\n')
#biden_data = pd.read_csv("../input/us-election-2020-tweets/hashtag_joebiden.csv",lineterminator='\n')

trump_data = pd.read_csv("hashtag_donaldtrump.csv",lineterminator='\n')
biden_data = pd.read_csv("hashtag_joebiden.csv",lineterminator='\n')

# %% [markdown]
# ## Trump

# %%
trump_data.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:01  1.316529e+18
# 2  2020-10-15 00:00:02  1.316529e+18
# 3  2020-10-15 00:00:02  1.316529e+18
# 4  2020-10-15 00:00:08  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  Usa 2020, Trump contro Facebook e Twitter: cop...   26.0            9.0
# 2  #Trump: As a student I used to hear for years,...    2.0            1.0
# 3  2 hours since last tweet from #Trump! Maybe he...    0.0            0.0
# 4  You get a tie! And you get a tie! #Trump ‘s ra...    4.0            3.0
#
#                source       user_id              user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08     El Sol Latino News  elsollatinonews
# 1    Social Mediaset   3.316176e+08                Tgcom24  MediasetTgcom24
# 2     Twitter Web App  8.436472e+06                 snarke           snarke
# 3       Trumpytweeter  8.283556e+17          Trumpytweeter    trumpytweeter
# 4  Twitter for iPhone  4.741380e+07  Rana Abtar - رنا أبتر        Ranaabtar
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Profilo ufficiale di Tgcom24: tutte le notizie...  ...
# 2  Will mock for food! Freelance writer, blogger,...  ...
# 3  If he doesn't tweet for some time, should we b...  ...
# 4  Washington Correspondent, Lebanese-American ,c...  ...
#
#   user_followers_count                 user_location        lat        long  \
# 0               1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1            1067661.0                           NaN        NaN         NaN
# 2               1185.0                      Portland  45.520247 -122.674195
# 3                 32.0                           NaN        NaN         NaN
# 4               5393.0                 Washington DC  38.894992  -77.036558
#
#          city                   country      continent                 state  \
# 0         NaN  United States of America  North America               Florida
# 1         NaN                       NaN            NaN                   NaN
# 2    Portland  United States of America  North America                Oregon
# 3         NaN                       NaN            NaN                   NaN
# 4  Washington  United States of America  North America  District of Columbia
#
#   state_code                   collected_at
# 0         FL            2020-10-21 00:00:00
# 1        NaN  2020-10-21 00:00:00.373216530
# 2         OR  2020-10-21 00:00:00.746433060
# 3        NaN  2020-10-21 00:00:01.119649591
# 4         DC  2020-10-21 00:00:01.492866121
#
# [5 rows x 21 columns]

# %%
trump_data.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  9.709190e+05  970919.000000  970919.000000  9.709190e+05
# mean   1.322494e+18       7.477011       1.698500  4.468311e+17
# std    2.555133e+15     158.058117      40.028419  5.544702e+17
# min    1.316529e+18       0.000000       0.000000  5.310000e+02
# 25%    1.320478e+18       0.000000       0.000000  2.169326e+08
# 50%    1.323612e+18       0.000000       0.000000  2.373392e+09
# 75%    1.324505e+18       1.000000       0.000000  1.078344e+18
# max    1.325589e+18   74084.000000   20491.000000  1.325581e+18
#
#        user_followers_count            lat           long
# count          9.709190e+05  445719.000000  445719.000000
# mean           2.260357e+04      35.697936     -40.369638
# std            3.042152e+05      18.823129      67.531751
# min            0.000000e+00     -90.000000    -175.202642
# 25%            7.700000e+01      32.701939     -96.796856
# 50%            4.410000e+02      39.783730     -74.006015
# 75%            2.066000e+03      46.603354       6.776314
# max            1.911533e+07      90.000000     179.048837

# %%
trump_data.isnull().sum()
# Out:
# created_at                   0
# tweet_id                     0
# tweet                        0
# likes                        0
# retweet_count                0
# source                     876
# user_id                      0
# user_name                   16
# user_screen_name             0
# user_description        101266
# user_join_date               0
# user_followers_count         0
# user_location           294953
# lat                     525200
# long                    525200
# city                    743732
# country                 528171
# continent               528154
# state                   650299
# state_code              670494
# collected_at                 0
# dtype: int64

# %%
trump_data=trump_data.drop(columns = ['tweet_id', 'collected_at', 'user_description','user_screen_name','user_join_date'])

# %%
trump_data.head()
# Out:
#             created_at                                              tweet  \
# 0  2020-10-15 00:00:01  #Elecciones2020 | En #Florida: #JoeBiden dice ...
# 1  2020-10-15 00:00:01  Usa 2020, Trump contro Facebook e Twitter: cop...
# 2  2020-10-15 00:00:02  #Trump: As a student I used to hear for years,...
# 3  2020-10-15 00:00:02  2 hours since last tweet from #Trump! Maybe he...
# 4  2020-10-15 00:00:08  You get a tie! And you get a tie! #Trump ‘s ra...
#
#    likes  retweet_count              source       user_id  \
# 0    0.0            0.0           TweetDeck  3.606665e+08
# 1   26.0            9.0    Social Mediaset   3.316176e+08
# 2    2.0            1.0     Twitter Web App  8.436472e+06
# 3    0.0            0.0       Trumpytweeter  8.283556e+17
# 4    4.0            3.0  Twitter for iPhone  4.741380e+07
#
#                user_name  user_followers_count                 user_location  \
# 0     El Sol Latino News                1860.0  Philadelphia, PA / Miami, FL
# 1                Tgcom24             1067661.0                           NaN
# 2                 snarke                1185.0                      Portland
# 3          Trumpytweeter                  32.0                           NaN
# 4  Rana Abtar - رنا أبتر                5393.0                 Washington DC
#
#          lat        long        city                   country      continent  \
# 0  25.774270  -80.193660         NaN  United States of America  North America
# 1        NaN         NaN         NaN                       NaN            NaN
# 2  45.520247 -122.674195    Portland  United States of America  North America
# 3        NaN         NaN         NaN                       NaN            NaN
# 4  38.894992  -77.036558  Washington  United States of America  North America
#
#                   state state_code
# 0               Florida         FL
# 1                   NaN        NaN
# 2                Oregon         OR
# 3                   NaN        NaN
# 4  District of Columbia         DC

# %%
trump_data=trump_data.dropna()

# %%
trump_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 199165 entries, 2 to 970912
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            199165 non-null  object
#  1   tweet                 199165 non-null  object
#  2   likes                 199165 non-null  float64
#  3   retweet_count         199165 non-null  float64
#  4   source                199165 non-null  object
#  5   user_id               199165 non-null  float64
#  6   user_name             199165 non-null  object
#  7   user_followers_count  199165 non-null  float64
#  8   user_location         199165 non-null  object
#  9   lat                   199165 non-null  float64
#  10  long                  199165 non-null  float64
#  11  city                  199165 non-null  object
#  12  country               199165 non-null  object
#  13  continent             199165 non-null  object
#  14  state                 199165 non-null  object
#  15  state_code            199165 non-null  object
# dtypes: float64(6), object(10)
# memory usage: 25.8+ MB

# %%
trump_data.describe()
# Out:
#                likes  retweet_count       user_id  user_followers_count  \
# count  199165.000000  199165.000000  1.991650e+05          1.991650e+05
# mean       11.449537       2.570748  2.962475e+17          3.219419e+04
# std       246.992555      62.097747  4.839031e+17          2.643791e+05
# min         0.000000       0.000000  3.471000e+03          0.000000e+00
# 25%         0.000000       0.000000  8.775513e+07          1.600000e+02
# 50%         0.000000       0.000000  5.794535e+08          7.880000e+02
# 75%         2.000000       0.000000  7.752435e+17          3.075000e+03
# max     74084.000000   20491.000000  1.325569e+18          1.321603e+07
#
#                  lat           long
# count  199165.000000  199165.000000
# mean       36.548171     -43.349355
# std        18.228199      65.770987
# min       -43.530955    -158.077849
# 25%        33.749099     -87.624421
# 50%        40.712728     -74.006015
# 75%        48.856697       2.351462
# max        64.837845     175.281788

# %%
trump_data.loc[:,'tweet_for'] = 'Trump'

# %%
trump_data.head()
# Out:
#              created_at                                              tweet  \
# 2   2020-10-15 00:00:02  #Trump: As a student I used to hear for years,...
# 4   2020-10-15 00:00:08  You get a tie! And you get a tie! #Trump ‘s ra...
# 11  2020-10-15 00:00:25  In 2020, #NYPost is being #censorship #CENSORE...
# 12  2020-10-15 00:00:26  #Trump #PresidentTrump #Trump2020LandslideVict...
# 13  2020-10-15 00:00:31  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...
#
#     likes  retweet_count               source       user_id  \
# 2     2.0            1.0      Twitter Web App  8.436472e+06
# 4     4.0            3.0   Twitter for iPhone  4.741380e+07
# 11    0.0            0.0   Twitter for iPhone  1.994033e+07
# 12    3.0            5.0  Twitter for Android  1.243315e+18
# 13    2.0            0.0      Twitter Web App  3.439562e+08
#
#                                             user_name  user_followers_count  \
# 2                                              snarke                1185.0
# 4                               Rana Abtar - رنا أبتر                5393.0
# 11  Change Illinois | Biden will increase taxes by...                1396.0
# 12                                       Ron Burgundy                 496.0
# 13                                    Sebastian White                2755.0
#
#                      user_location        lat        long               city  \
# 2                         Portland  45.520247 -122.674195           Portland
# 4                    Washington DC  38.894992  -77.036558         Washington
# 11               Chicago, Illinois  41.875562  -87.624421            Chicago
# 12                   San Diego, CA  32.717421 -117.162771          San Diego
# 13  Edinburgh ~ Heart of Scotland!  55.953346   -3.188375  City of Edinburgh
#
#                      country      continent                 state state_code  \
# 2   United States of America  North America                Oregon         OR
# 4   United States of America  North America  District of Columbia         DC
# 11  United States of America  North America              Illinois         IL
# 12  United States of America  North America            California         CA
# 13            United Kingdom         Europe              Scotland        SCT
#
#    tweet_for
# 2      Trump
# 4      Trump
# 11     Trump
# 12     Trump
# 13     Trump

# %% [markdown]
# ## Biden

# %%
biden_data.head()
# Out:
#             created_at      tweet_id  \
# 0  2020-10-15 00:00:01  1.316529e+18
# 1  2020-10-15 00:00:18  1.316529e+18
# 2  2020-10-15 00:00:20  1.316529e+18
# 3  2020-10-15 00:00:21  1.316529e+18
# 4  2020-10-15 00:00:22  1.316529e+18
#
#                                                tweet  likes  retweet_count  \
# 0  #Elecciones2020 | En #Florida: #JoeBiden dice ...    0.0            0.0
# 1  #HunterBiden #HunterBidenEmails #JoeBiden #Joe...    0.0            0.0
# 2  @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...    0.0            0.0
# 3  @chrislongview Watching and setting dvr. Let’s...    0.0            0.0
# 4  #censorship #HunterBiden #Biden #BidenEmails #...    1.0            0.0
#
#                source       user_id           user_name user_screen_name  \
# 0           TweetDeck  3.606665e+08  El Sol Latino News  elsollatinonews
# 1    Twitter for iPad  8.099044e+08         Cheri A. 🇺🇸     Biloximeemaw
# 2     Twitter Web App  3.494182e+09          Flag Waver      Flag_Wavers
# 3  Twitter for iPhone  8.242596e+17       Michelle Ferg    MichelleFerg4
# 4     Twitter Web App  1.032807e+18      the Gold State    theegoldstate
#
#                                     user_description  ...  \
# 0  🌐 Noticias de interés para latinos de la costa...  ...
# 1  Locked and loaded Meemaw. Love God, my family ...  ...
# 2                                                NaN  ...
# 3                                                NaN  ...
# 4  A Silicon Valley #independent #News #Media #St...  ...
#
#   user_followers_count                 user_location        lat        long  \
# 0               1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1               6628.0                           NaN        NaN         NaN
# 2               1536.0         Golden Valley Arizona  46.304036 -109.171431
# 3                 27.0                           NaN        NaN         NaN
# 4                390.0               California, USA  36.701463 -118.755997
#
#    city                   country      continent       state state_code  \
# 0   NaN  United States of America  North America     Florida         FL
# 1   NaN                       NaN            NaN         NaN        NaN
# 2   NaN  United States of America  North America     Montana         MT
# 3   NaN                       NaN            NaN         NaN        NaN
# 4   NaN  United States of America  North America  California         CA
#
#                     collected_at
# 0            2020-10-21 00:00:00
# 1  2020-10-21 00:00:00.517827283
# 2  2020-10-21 00:00:01.035654566
# 3  2020-10-21 00:00:01.553481849
# 4  2020-10-21 00:00:02.071309132
#
# [5 rows x 21 columns]

# %%
biden_data.describe()
# Out:
#            tweet_id          likes  retweet_count       user_id  \
# count  7.768860e+05  776886.000000  776886.000000  7.768860e+05
# mean   1.322844e+18      10.161164       2.131331  4.532033e+17
# std    2.585560e+15     390.974423      96.661527  5.573483e+17
# min    1.316529e+18       0.000000       0.000000  1.081000e+03
# 25%    1.320870e+18       0.000000       0.000000  2.257285e+08
# 50%    1.323899e+18       0.000000       0.000000  2.464208e+09
# 75%    1.325115e+18       2.000000       0.000000  1.088044e+18
# max    1.325589e+18  165702.000000   63473.000000  1.325575e+18
#
#        user_followers_count            lat           long
# count          7.768860e+05  355293.000000  355293.000000
# mean           2.884994e+04      35.104203     -41.979660
# std            4.141085e+05      17.907910      67.823724
# min            0.000000e+00     -79.406307    -172.120051
# 25%            7.400000e+01      31.816038     -97.268406
# 50%            4.280000e+02      39.783730     -74.006015
# 75%            2.081000e+03      43.653482       5.966069
# max            8.241710e+07      90.000000     179.048837

# %%
biden_data.isnull().sum()
# Out:
# created_at                   0
# tweet_id                     0
# tweet                        0
# likes                        0
# retweet_count                0
# source                     713
# user_id                      0
# user_name                   18
# user_screen_name             0
# user_description         82006
# user_join_date               0
# user_followers_count         0
# user_location           233791
# lat                     421593
# long                    421593
# city                    590014
# country                 423107
# continent               423089
# state                   516691
# state_code              532277
# collected_at                 0
# dtype: int64

# %%
biden_data=biden_data.drop(columns = ['tweet_id', 'collected_at', 'user_description','user_screen_name','user_join_date'])

# %%
biden_data.head()
# Out:
#             created_at                                              tweet  \
# 0  2020-10-15 00:00:01  #Elecciones2020 | En #Florida: #JoeBiden dice ...
# 1  2020-10-15 00:00:18  #HunterBiden #HunterBidenEmails #JoeBiden #Joe...
# 2  2020-10-15 00:00:20  @IslandGirlPRV @BradBeauregardJ @MeidasTouch T...
# 3  2020-10-15 00:00:21  @chrislongview Watching and setting dvr. Let’s...
# 4  2020-10-15 00:00:22  #censorship #HunterBiden #Biden #BidenEmails #...
#
#    likes  retweet_count              source       user_id           user_name  \
# 0    0.0            0.0           TweetDeck  3.606665e+08  El Sol Latino News
# 1    0.0            0.0    Twitter for iPad  8.099044e+08         Cheri A. 🇺🇸
# 2    0.0            0.0     Twitter Web App  3.494182e+09          Flag Waver
# 3    0.0            0.0  Twitter for iPhone  8.242596e+17       Michelle Ferg
# 4    1.0            0.0     Twitter Web App  1.032807e+18      the Gold State
#
#    user_followers_count                 user_location        lat        long  \
# 0                1860.0  Philadelphia, PA / Miami, FL  25.774270  -80.193660
# 1                6628.0                           NaN        NaN         NaN
# 2                1536.0         Golden Valley Arizona  46.304036 -109.171431
# 3                  27.0                           NaN        NaN         NaN
# 4                 390.0               California, USA  36.701463 -118.755997
#
#   city                   country      continent       state state_code
# 0  NaN  United States of America  North America     Florida         FL
# 1  NaN                       NaN            NaN         NaN        NaN
# 2  NaN  United States of America  North America     Montana         MT
# 3  NaN                       NaN            NaN         NaN        NaN
# 4  NaN  United States of America  North America  California         CA

# %%
biden_data=biden_data.dropna()

# %%
biden_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 164673 entries, 6 to 776881
# Data columns (total 16 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   created_at            164673 non-null  object
#  1   tweet                 164673 non-null  object
#  2   likes                 164673 non-null  float64
#  3   retweet_count         164673 non-null  float64
#  4   source                164673 non-null  object
#  5   user_id               164673 non-null  float64
#  6   user_name             164673 non-null  object
#  7   user_followers_count  164673 non-null  float64
#  8   user_location         164673 non-null  object
#  9   lat                   164673 non-null  float64
#  10  long                  164673 non-null  float64
#  11  city                  164673 non-null  object
#  12  country               164673 non-null  object
#  13  continent             164673 non-null  object
#  14  state                 164673 non-null  object
#  15  state_code            164673 non-null  object
# dtypes: float64(6), object(10)
# memory usage: 21.4+ MB

# %%
biden_data.describe()
# Out:
#                likes  retweet_count       user_id  user_followers_count  \
# count  164673.000000  164673.000000  1.646730e+05          1.646730e+05
# mean       16.784579       3.361729  3.205418e+17          3.967030e+04
# std       555.000547      84.268318  5.005052e+17          3.385202e+05
# min         0.000000       0.000000  1.081000e+03          0.000000e+00
# 25%         0.000000       0.000000  9.641200e+07          1.460000e+02
# 50%         1.000000       0.000000  7.704772e+08          7.280000e+02
# 75%         2.000000       0.000000  8.225108e+17          3.189000e+03
# max    165702.000000   20615.000000  1.325550e+18          1.321635e+07
#
#                  lat           long
# count  164673.000000  164673.000000
# mean       35.963481     -45.077640
# std        17.245318      65.680267
# min       -43.530955    -158.077849
# 25%        32.776272     -87.624421
# 50%        39.962260     -74.006015
# 75%        45.497216       2.351462
# max        64.837845     176.167505

# %%
biden_data.loc[:,'tweet_for']='Biden'

# %%
biden_data.head()
# Out:
#              created_at                                              tweet  \
# 6   2020-10-15 00:00:25  In 2020, #NYPost is being #censorship #CENSORE...
# 17  2020-10-15 00:01:23  Comments on this? "Do Democrats Understand how...
# 22  2020-10-15 00:01:47  Twitter is doing everything they can to help D...
# 25  2020-10-15 00:01:57  @RealJamesWoods #BidenCrimeFamily #JoeBiden #H...
# 28  2020-10-15 00:02:05  #Trump #Obama #Clinton #Biden\n\n#ManWomanPers...
#
#     likes  retweet_count               source       user_id  \
# 6     0.0            0.0   Twitter for iPhone  1.994033e+07
# 17    0.0            0.0      Twitter Web App  1.016593e+08
# 22    1.0            0.0   Twitter for iPhone  1.139962e+18
# 25    0.0            0.0  Twitter for Android  1.300837e+18
# 28    0.0            0.0   Twitter for iPhone  1.321631e+08
#
#                                             user_name  user_followers_count  \
# 6   Change Illinois | Biden will increase taxes by...                1397.0
# 17                                        John Ubaldi                  83.0
# 22                                            Wynward                   2.0
# 25                                           Sam KEYS                  29.0
# 28                                 Saroop Rooprai FIA                 841.0
#
#         user_location        lat        long         city  \
# 6   Chicago, Illinois  41.875562  -87.624421      Chicago
# 17     Tampa, Florida  27.947760  -82.458444        Tampa
# 22      Hollywood, FL  34.098003 -118.329523  Los Angeles
# 25    Los Angeles, CA  34.053691 -118.242766  Los Angeles
# 28         London, UK  51.507322   -0.127647       London
#
#                      country      continent       state state_code tweet_for
# 6   United States of America  North America    Illinois         IL     Biden
# 17  United States of America  North America     Florida         FL     Biden
# 22  United States of America  North America  California         CA     Biden
# 25  United States of America  North America  California         CA     Biden
# 28            United Kingdom         Europe     England        ENG     Biden

# %% [markdown]
# ## Combined Trump + Biden

# %%
total_data=pd.concat([trump_data,biden_data])
total_data.sort_values(by='created_at')
# Out:
#                  created_at  \
# 2       2020-10-15 00:00:02
# 4       2020-10-15 00:00:08
# 6       2020-10-15 00:00:25
# 11      2020-10-15 00:00:25
# 12      2020-10-15 00:00:26
# ...                     ...
# 970896  2020-11-08 23:58:54
# 776876  2020-11-08 23:59:16
# 970907  2020-11-08 23:59:25
# 970912  2020-11-08 23:59:38
# 776881  2020-11-08 23:59:38
#
#                                                     tweet  likes  \
# 2       #Trump: As a student I used to hear for years,...    2.0
# 4       You get a tie! And you get a tie! #Trump ‘s ra...    4.0
# 6       In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 11      In 2020, #NYPost is being #censorship #CENSORE...    0.0
# 12      #Trump #PresidentTrump #Trump2020LandslideVict...    3.0
# ...                                                   ...    ...
# 970896  @TeamTrump @alex281832 #Trump is being made to...    1.0
# 776876  Mr. #Biden, tear down that wall (with #Mexico)...    1.0
# 970907  Donald Trump, Moscow, 1996, shared by @oooroma...    8.0
# 970912  Stop laying @CNN !\n#Paris and #London dont gi...    0.0
# 776881  Stop laying @CNN !\n#Paris and #London dont gi...    0.0
#
#         retweet_count               source       user_id  \
# 2                 1.0      Twitter Web App  8.436472e+06
# 4                 3.0   Twitter for iPhone  4.741380e+07
# 6                 0.0   Twitter for iPhone  1.994033e+07
# 11                0.0   Twitter for iPhone  1.994033e+07
# 12                5.0  Twitter for Android  1.243315e+18
# ...               ...                  ...           ...
# 970896            0.0  Twitter for Android  5.008862e+08
# 776876            0.0   Twitter for iPhone  3.772296e+08
# 970907            3.0      Twitter Web App  3.881374e+08
# 970912            0.0   Twitter for iPhone  3.873620e+08
# 776881            0.0   Twitter for iPhone  3.873620e+08
#
#                                                 user_name  \
# 2                                                  snarke
# 4                                   Rana Abtar - رنا أبتر
# 6       Change Illinois | Biden will increase taxes by...
# 11      Change Illinois | Biden will increase taxes by...
# 12                                           Ron Burgundy
# ...                                                   ...
# 970896                                         Ken Noble😎
# 776876                                          Tim Welch
# 970907                              Elisabeth Schimpfössl
# 970912                                            flaquet
# 776881                                            flaquet
#
#         user_followers_count      user_location        lat        long  \
# 2                     1185.0           Portland  45.520247 -122.674195
# 4                     5393.0      Washington DC  38.894992  -77.036558
# 6                     1397.0  Chicago, Illinois  41.875562  -87.624421
# 11                    1396.0  Chicago, Illinois  41.875562  -87.624421
# 12                     496.0      San Diego, CA  32.717421 -117.162771
# ...                      ...                ...        ...         ...
# 970896                 453.0   West London, UK   51.532568   -0.480700
# 776876                 444.0       Auckland, NZ -36.852095  174.763180
# 970907                 586.0    London, England  51.507322   -0.127647
# 970912                  27.0              PARIS  48.856697    2.351462
# 776881                  27.0              PARIS  48.856697    2.351462
#
#               city                   country      continent  \
# 2         Portland  United States of America  North America
# 4       Washington  United States of America  North America
# 6          Chicago  United States of America  North America
# 11         Chicago  United States of America  North America
# 12       San Diego  United States of America  North America
# ...            ...                       ...            ...
# 970896      London            United Kingdom         Europe
# 776876    Auckland               New Zealand        Oceania
# 970907      London            United Kingdom         Europe
# 970912       Paris                    France         Europe
# 776881       Paris                    France         Europe
#
#                        state state_code tweet_for
# 2                     Oregon         OR     Trump
# 4       District of Columbia         DC     Trump
# 6                   Illinois         IL     Biden
# 11                  Illinois         IL     Trump
# 12                California         CA     Trump
# ...                      ...        ...       ...
# 970896               England        ENG     Trump
# 776876              Auckland        AUK     Biden
# 970907               England        ENG     Trump
# 970912         Ile-de-France        IDF     Trump
# 776881         Ile-de-France        IDF     Biden
#
# [363838 rows x 17 columns]

# %%
trump_tweets=total_data.query('(tweet_for=="Trump")').tweet.sort_values(ascending=False).count()
biden_tweets=total_data.query('(tweet_for=="Biden")').tweet.sort_values(ascending=False).count()

trump_likes=total_data.query('(tweet_for=="Trump")').likes.count()
biden_likes=total_data.query('(tweet_for=="Biden")').likes.count()

# %%
x_pos=('Donald Trump','Joe Biden')
y_pos=np.arange(len(x_pos))
performance = [trump_tweets,biden_tweets]
plt.figure(figsize=(3,5))
plt.bar(y_pos,performance,align='center',color=['red','blue'])
plt.xticks(y_pos,x_pos)
plt.ylabel('Number of tweets')
plt.title('Trump vs Biden for tweets')

plt.show()

# %%
x_pos=('Donald Trump','Joe Biden')
y_pos=np.arange(len(x_pos))
performance = [trump_likes,biden_likes]
plt.figure(figsize=(3,5))
plt.bar(y_pos,performance,align='center',color=['red','blue'])
plt.xticks(y_pos,x_pos)
plt.ylabel('Number of likes')
plt.title('Trump vs Biden for likes')

plt.show()

# %%
print("Count of duplicates: {}".format(total_data.duplicated(subset=["tweet"]).sum()))
# Out:
# Count of duplicates: 50326

# %%
total_data['created_at']=pd.to_datetime(total_data['created_at'])
plt.figure(figsize=(15,5))
ax=total_data.created_at.dt.date.value_counts().sort_index().plot.bar(rot=45,color='green')
plt.setp(ax.get_xticklabels(),fontsize=9)
plt.ylabel('Number of Tweets')
plt.title('Frequency of Tweets per day')
plt.show()

# %%
tweet_max=total_data.loc[total_data['retweet_count'].idxmax()]
print(f"Tweet is - \n\n'{tweet_max.tweet}'\n\nretweet_count({tweet_max.retweet_count} times)")
# Out:
# Tweet is -
#
# 'America Assembled!🇺🇸🎉
#
# @JoeBiden @KamalaHarris @BarackObama
# @ChrisEvans  @MarkRuffalo @RobertDowneyJr @brielarson @AOC @staceyabrams @michaelb4jordan @Russo_Brothers
# #Election2020 #ElectionResults2020 #joebiden #DonaldTrump #BidenHarris2020 #avengers #endgame https://t.co/cDl1VsFbOo'
#
# retweet_count(20615.0 times)

# %%
print(f'Unique retweets {total_data.retweet_count.nunique()}')
# Out:
# Unique retweets 632

# %%
trump_country_y=total_data.query('(tweet_for=="Trump")').groupby(by='country').count().tweet.sort_values(ascending=False)
trump_country_x=total_data.query('(tweet_for=="Trump")').groupby(by='country').count().tweet.sort_values(ascending=False).index

biden_country_y=total_data.query('(tweet_for=="Biden")').groupby(by='country').count().tweet.sort_values(ascending=False)
biden_country_x=total_data.query('(tweet_for=="Biden")').groupby(by='country').count().tweet.sort_values(ascending=False).index

# %%
print(f'Unique countries {total_data.country.nunique()}')
# Out:
# Unique countries 51

# %%
total_data.head()
# Out:
#             created_at                                              tweet  \
# 2  2020-10-15 00:00:02  #Trump: As a student I used to hear for years,...
# 4  2020-10-15 00:00:08  You get a tie! And you get a tie! #Trump ‘s ra...
# 11 2020-10-15 00:00:25  In 2020, #NYPost is being #censorship #CENSORE...
# 12 2020-10-15 00:00:26  #Trump #PresidentTrump #Trump2020LandslideVict...
# 13 2020-10-15 00:00:31  @Susan_Hutch @JoeBiden #Ukraine @RealDonaldTru...
#
#     likes  retweet_count               source       user_id  \
# 2     2.0            1.0      Twitter Web App  8.436472e+06
# 4     4.0            3.0   Twitter for iPhone  4.741380e+07
# 11    0.0            0.0   Twitter for iPhone  1.994033e+07
# 12    3.0            5.0  Twitter for Android  1.243315e+18
# 13    2.0            0.0      Twitter Web App  3.439562e+08
#
#                                             user_name  user_followers_count  \
# 2                                              snarke                1185.0
# 4                               Rana Abtar - رنا أبتر                5393.0
# 11  Change Illinois | Biden will increase taxes by...                1396.0
# 12                                       Ron Burgundy                 496.0
# 13                                    Sebastian White                2755.0
#
#                      user_location        lat        long               city  \
# 2                         Portland  45.520247 -122.674195           Portland
# 4                    Washington DC  38.894992  -77.036558         Washington
# 11               Chicago, Illinois  41.875562  -87.624421            Chicago
# 12                   San Diego, CA  32.717421 -117.162771          San Diego
# 13  Edinburgh ~ Heart of Scotland!  55.953346   -3.188375  City of Edinburgh
#
#                      country      continent                 state state_code  \
# 2   United States of America  North America                Oregon         OR
# 4   United States of America  North America  District of Columbia         DC
# 11  United States of America  North America              Illinois         IL
# 12  United States of America  North America            California         CA
# 13            United Kingdom         Europe              Scotland        SCT
#
#    tweet_for
# 2      Trump
# 4      Trump
# 11     Trump
# 12     Trump
# 13     Trump

# %%
total_data["country"] = total_data["country"].replace({"United States":"United States of America"})
data = total_data[(total_data.country.isin(total_data.country.value_counts()[:10].index))].groupby(["country", "tweet_for"]).count().sort_values(by=["user_id"], ascending=False)["user_id"].reset_index()
ax=sns.catplot(x="country", y="user_id", hue="tweet_for", kind="bar", aspect=21/8,palette=['r', 'b'], data=data).set( xlabel='Country', ylabel='Number of Tweets',title='Trump vs Biden tweets top 10 by country')
ax.set_xticklabels(rotation=45)

# %%
plt.figure(figsize=(15,9))
data=total_data.loc[total_data['country'] == "United States of America"]
#data=data.groupby(by='state').count().tweet.sort_values(ascending=False)
bar_plot=sns.countplot(x = 'state', hue = 'tweet_for', data = data, palette = 'magma')
#gr.set_xticklabels(gr.get_xticklabels(), rotation=90)
plt.xticks(rotation=90)
#plt.xlim(0, 10)
plt.ylabel('Number of Tweets')
plt.title('Trump vs Biden tweets by state in USA')
plt.show()

# %%
data = total_data[(total_data.country == "United States of America") & (total_data.state.isin(total_data.state.value_counts()[:15].index))].groupby(["state", "tweet_for"]).count().sort_values(by=["user_id"], ascending=False)["user_id"].reset_index()
ax=sns.catplot(x="state", y="user_id", hue="tweet_for", kind="bar", aspect=21/8,palette=['r', 'b'], data=data).set( xlabel='State', ylabel='Number of Tweets',title='Trump vs Biden tweets top 10 by state in USA')
ax.set_xticklabels(rotation=45)

# %%
total_data['source'].value_counts(ascending=False)[:10]
# Out:
# Twitter for iPhone      120054
# Twitter Web App         116612
# Twitter for Android      80864
# Twitter for iPad         12551
# TweetDeck                 9247
# Instagram                 3969
# Hootsuite Inc.            2949
# Buffer                    2098
# dlvr.it                    942
# Twitter Media Studio       883
# Name: source, dtype: int64

# %%
data = total_data[(total_data.source.isin(total_data.source.value_counts()[:7].index))].groupby(["source", "tweet_for"]).count().sort_values(by=["user_id"], ascending=False)["user_id"].reset_index()
ax=sns.catplot(x="source", y="user_id", hue="tweet_for", kind="bar", aspect=21/8,palette=['r', 'b'], data=data).set( xlabel='Source', ylabel='Number of Tweets',title='Trump vs Biden tweets top 10 by Source')
ax.set_xticklabels(rotation=45)

# %%
data = total_data[(total_data.city.isin(total_data.city.value_counts()[:15].index))].groupby(["city", "tweet_for"]).count().sort_values(by=["user_id"], ascending=False)["user_id"].reset_index()
ax=sns.catplot(x="city", y="user_id", hue="tweet_for", kind="bar", aspect=21/8,palette=['r', 'b'], data=data).set( xlabel='City', ylabel='Number of Tweets',title='Trump vs Biden tweets top 10 by City')
ax.set_xticklabels(rotation=45)

# %%
#data = total_data[(total_data.user_name.isin(total_data.user_name.value_counts()[:15].index))].groupby(["user_name", "tweet_for"]).count().sort_values(by=["user_id"], ascending=False)["user_id"].reset_index()
#ax=sns.catplot(x="user_name", y="user_id", hue="tweet_for", kind="bar", aspect=21/8,palette=['r', 'b'], data=data).set( xlabel='City', ylabel='Number of Tweets',title='Trump vs Biden tweets top 10 by City')
#ax.set_xticklabels(rotation=45)

# %%
y = total_data.query('tweet_for == "Trump"').groupby(by='user_name').count().tweet.sort_values(ascending=False)[:15]
x = total_data.query('tweet_for == "Trump"').groupby(by='user_name').count().tweet.sort_values(ascending=False)[:15].index
plt.figure(figsize = (15, 7)) 
plt.bar(x, y,color='red')
plt.xticks(rotation=90)
plt.xlabel("Names") 
plt.ylabel("Count") 
plt.title("Trump hashtag based most active") 
plt.show()

# %%
y = total_data.query('tweet_for == "Biden"').groupby(by='user_name').count().tweet.sort_values(ascending=False)[:15]
x = total_data.query('tweet_for == "Biden"').groupby(by='user_name').count().tweet.sort_values(ascending=False)[:15].index
plt.figure(figsize = (15, 7)) 
plt.bar(x, y,color='blue')
plt.xticks(rotation=90)
plt.xlabel("Names") 
plt.ylabel("Count") 
plt.title("Biden hashtag based 15 most active") 
plt.show()

# %%
y = total_data.query('tweet_for == "Trump"').sort_values('user_followers_count',ascending=False).drop_duplicates(['user_name']).user_followers_count[:15]
x = total_data.query('tweet_for == "Trump"').sort_values('user_followers_count',ascending=False).drop_duplicates(['user_name']).user_name[:15]
plt.figure(figsize = (15, 7)) 
plt.bar(x, y,color='red')
plt.xticks(rotation=90)
plt.xlabel("Names") 
plt.ylabel("Count") 
plt.title("Trump hastag based 15 most famous followers") 
plt.show()

# %%
y = total_data.query('tweet_for == "Biden"').sort_values('user_followers_count',ascending=False).drop_duplicates(['user_name']).user_followers_count[:15]
x = total_data.query('tweet_for == "Biden"').sort_values('user_followers_count',ascending=False).drop_duplicates(['user_name']).user_name[:15]
plt.figure(figsize = (15, 7)) 
plt.bar(x, y,color='blue')
plt.xticks(rotation=90)
plt.xlabel("Names") 
plt.ylabel("Count") 
plt.title("Trump hastag based 15 most famous followers") 
plt.show()

# %% [markdown]
# # Sentimental Analysis

# %%
stop=stopwords.words('english')

# %%
def clean(text):
 
    text = re.sub(r':', '', str(text))
    text = re.sub(r'‚Ä¶', '', str(text))
    text = re.sub('@[A-Za-z0–9]+', '', str(text))               
    text = re.sub('#', '', str(text)) # Removing '#' hash tag
    text = re.sub('https?:\/\/\S+', '', str(text)) # Removing hyperlink
    #replace consecutive non-ASCII characters with a space
    text = re.sub(r'[^\x00-\x7F]+',' ',str(text))
    text = str(text).lower()
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub(r'#','',text)
    text = re.sub(r'RT[\s]+','',text)
    text = re.sub(r'[^\w]', ' ', text)
    text = re.sub('https', '', text)
    text = re.sub('https ', '', text)
    text = re.sub('co', '', text)

    return text

# %%
def word_cloud(wd_list, title):
    stopwords = set(STOPWORDS)
    all_words = ' '.join([text for text in wd_list])
    wordcloud = WordCloud(
        background_color='black',
        stopwords=stop,
        width=1600,
        height=800,
        random_state=1,
        colormap='jet',
        max_words=800,
        max_font_size=200).generate(all_words)
    plt.figure(figsize=(21,7))
    plt.axis('off')
    plt.title(title)
    plt.imshow(wordcloud, interpolation="bilinear");

# %%
def find_at(text):
    text= re.findall(r"@(\w+)",text)
    return text

def find_hashtag(text):
    text= re.findall(r"#(\w+)",text)
    return text

total_data["at_rate"] = total_data.tweet.apply(find_at)
total_data["hashtags"] = total_data.tweet.apply(find_hashtag)

# %%
total_data.head()

# %%
def get_hashtags(df):
    df["hashtags"] = df.tweet.apply(lambda x: ",".join([tag.strip("#") for tag in x.split() if tag.startswith("#")]))
    allhashtags = ",".join(df["hashtags"].values.tolist()).split(",")
    allhashtags = [i.upper() for i in allhashtags if i != ""]
    
    return allhashtags

# %% [markdown]
# ## Trump

# %%
trump_data_clean = total_data.query('(tweet_for == "Trump")').sort_values('created_at',ascending = False).drop_duplicates(['user_name'])
trump_data_clean['clean_tweet'] = trump_data_clean['tweet'].apply(clean)

# %%
trump_blob = [TextBlob(desc) for desc in trump_data_clean['clean_tweet']]
trump_data_clean['polarity'] = [b.sentiment.polarity for b in trump_blob]
trump_data_clean['subjectivity'] = [b.sentiment.subjectivity for b in trump_blob]
trump_data_clean
# Out:
#                 created_at                                              tweet  \
# 970912 2020-11-08 23:59:38  Stop laying @CNN !\n#Paris and #London dont gi...
# 970907 2020-11-08 23:59:25  Donald Trump, Moscow, 1996, shared by @oooroma...
# 970896 2020-11-08 23:58:54  @TeamTrump @alex281832 #Trump is being made to...
# 970895 2020-11-08 23:58:51  Have you know decency #Trump  @GOP? Do you kno...
# 970890 2020-11-08 23:58:44  Cómo pasó el abogado de Trump de un hotel a un...
# ...                    ...                                                ...
# 176    2020-10-15 00:09:02  #BidenHarris #BidenHarris #BidenHarris #BidenH...
# 173    2020-10-15 00:08:52  The President @realDonaldTrump got impeached f...
# 109    2020-10-15 00:05:50  @JoeBiden #BidenHarris2020 #DonaldTrump #Hunte...
# 75     2020-10-15 00:03:38               @JoeBiden #donaldtrump 4 more years!
# 29     2020-10-15 00:01:30  @karatblood @KazePlays_JC Grab @realDonaldTrum...
#
#         likes  retweet_count               source       user_id  \
# 970912    0.0            0.0   Twitter for iPhone  3.873620e+08
# 970907    8.0            3.0      Twitter Web App  3.881374e+08
# 970896    1.0            0.0  Twitter for Android  5.008862e+08
# 970895    3.0            0.0      Twitter Web App  4.835231e+07
# 970890    0.0            1.0      Twitter Web App  8.496398e+07
# ...       ...            ...                  ...           ...
# 176       0.0            0.0   Twitter for iPhone  7.402017e+17
# 173       0.0            0.0   Twitter for iPhone  1.382486e+08
# 109       1.0            0.0  Twitter for Android  7.615802e+17
# 75        0.0            0.0      Twitter Web App  1.657854e+07
# 29        2.0            0.0   Twitter for iPhone  3.602439e+07
#
#                                      user_name  user_followers_count  \
# 970912                                 flaquet                  27.0
# 970907                   Elisabeth Schimpfössl                 586.0
# 970896                              Ken Noble😎                 453.0
# 970895  Linda "I Voted for Biden" Kenney Baden                3024.0
# 970890                          Impacto Latino                1517.0
# ...                                        ...                   ...
# 176                                  Americana                  58.0
# 173                            Pedro Gutierrez                2366.0
# 109                                 Joe Levija                  58.0
# 75                           Scott Seifferlein                 430.0
# 29                                      Baylee                1952.0
#
#                   user_location        lat        long          city  \
# 970912                    PARIS  48.856697    2.351462         Paris
# 970907          London, England  51.507322   -0.127647        London
# 970896         West London, UK   51.532568   -0.480700        London
# 970895            New York, USA  40.712728  -74.006015      New York
# 970890            New York City  40.712728  -74.006015      New York
# ...                         ...        ...         ...           ...
# 176                 Phoenix, AZ  33.448437 -112.074142       Phoenix
# 173                 Chicago, IL  41.875562  -87.624421       Chicago
# 109               Fitchburg, WI  42.590366  -71.811984     Fitchburg
# 75                 Grand Rapids  42.963241  -85.667864  Grand Rapids
# 29      Western Washington, USA  41.882823  -87.686307       Chicago
#
#                          country      continent          state state_code  \
# 970912                    France         Europe  Ile-de-France        IDF
# 970907            United Kingdom         Europe        England        ENG
# 970896            United Kingdom         Europe        England        ENG
# 970895  United States of America  North America       New York         NY
# 970890  United States of America  North America       New York         NY
# ...                          ...            ...            ...        ...
# 176     United States of America  North America        Arizona         AZ
# 173     United States of America  North America       Illinois         IL
# 109     United States of America  North America  Massachusetts         MA
# 75      United States of America  North America       Michigan         MI
# 29      United States of America  North America       Illinois         IL
#
#        tweet_for                                        clean_tweet  polarity  \
# 970912     Trump  stop laying   paris and london dont give a fuc...      -0.4
# 970907     Trump  donald trump  mosw    shared by  trump   t  uw...       0.0
# 970896     Trump    trump is being made to embrace defeat via me...      -0.5
# 970895     Trump  have you know decency trump    do you know wha...      -0.6
# 970890     Trump  c mo pas  el abogado de trump de un hotel a un...       0.0
# ...          ...                                                ...       ...
# 176        Trump  bidenharris bidenharris bidenharris bidenharri...       0.0
# 173        Trump  the president  got impeached for something joe...       0.0
# 109        Trump            donaldtrump hunterbiden   t  tbdfpoedzx       0.0
# 75         Trump                           donaldtrump  more years        0.5
# 29         Trump   _jc grab  by the balls  amp  chuck the bastar...       0.0
#
#         subjectivity
# 970912           0.6
# 970907           0.0
# 970896           0.7
# 970895           0.7
# 970890           0.0
# ...              ...
# 176              0.0
# 173              0.0
# 109              0.0
# 75               0.5
# 29               1.0
#
# [55498 rows x 20 columns]

# %%
trump_data_clean.loc[trump_data_clean.polarity > 0,'sentiment'] = 'positive'
trump_data_clean.loc[trump_data_clean.polarity == 0,'sentiment'] = 'neutral'
trump_data_clean.loc[trump_data_clean.polarity < 0,'sentiment'] = 'negative'
trump_data_clean
# Out:
#                 created_at                                              tweet  \
# 970912 2020-11-08 23:59:38  Stop laying @CNN !\n#Paris and #London dont gi...
# 970907 2020-11-08 23:59:25  Donald Trump, Moscow, 1996, shared by @oooroma...
# 970896 2020-11-08 23:58:54  @TeamTrump @alex281832 #Trump is being made to...
# 970895 2020-11-08 23:58:51  Have you know decency #Trump  @GOP? Do you kno...
# 970890 2020-11-08 23:58:44  Cómo pasó el abogado de Trump de un hotel a un...
# ...                    ...                                                ...
# 176    2020-10-15 00:09:02  #BidenHarris #BidenHarris #BidenHarris #BidenH...
# 173    2020-10-15 00:08:52  The President @realDonaldTrump got impeached f...
# 109    2020-10-15 00:05:50  @JoeBiden #BidenHarris2020 #DonaldTrump #Hunte...
# 75     2020-10-15 00:03:38               @JoeBiden #donaldtrump 4 more years!
# 29     2020-10-15 00:01:30  @karatblood @KazePlays_JC Grab @realDonaldTrum...
#
#         likes  retweet_count               source       user_id  \
# 970912    0.0            0.0   Twitter for iPhone  3.873620e+08
# 970907    8.0            3.0      Twitter Web App  3.881374e+08
# 970896    1.0            0.0  Twitter for Android  5.008862e+08
# 970895    3.0            0.0      Twitter Web App  4.835231e+07
# 970890    0.0            1.0      Twitter Web App  8.496398e+07
# ...       ...            ...                  ...           ...
# 176       0.0            0.0   Twitter for iPhone  7.402017e+17
# 173       0.0            0.0   Twitter for iPhone  1.382486e+08
# 109       1.0            0.0  Twitter for Android  7.615802e+17
# 75        0.0            0.0      Twitter Web App  1.657854e+07
# 29        2.0            0.0   Twitter for iPhone  3.602439e+07
#
#                                      user_name  user_followers_count  \
# 970912                                 flaquet                  27.0
# 970907                   Elisabeth Schimpfössl                 586.0
# 970896                              Ken Noble😎                 453.0
# 970895  Linda "I Voted for Biden" Kenney Baden                3024.0
# 970890                          Impacto Latino                1517.0
# ...                                        ...                   ...
# 176                                  Americana                  58.0
# 173                            Pedro Gutierrez                2366.0
# 109                                 Joe Levija                  58.0
# 75                           Scott Seifferlein                 430.0
# 29                                      Baylee                1952.0
#
#                   user_location        lat  ...          city  \
# 970912                    PARIS  48.856697  ...         Paris
# 970907          London, England  51.507322  ...        London
# 970896         West London, UK   51.532568  ...        London
# 970895            New York, USA  40.712728  ...      New York
# 970890            New York City  40.712728  ...      New York
# ...                         ...        ...  ...           ...
# 176                 Phoenix, AZ  33.448437  ...       Phoenix
# 173                 Chicago, IL  41.875562  ...       Chicago
# 109               Fitchburg, WI  42.590366  ...     Fitchburg
# 75                 Grand Rapids  42.963241  ...  Grand Rapids
# 29      Western Washington, USA  41.882823  ...       Chicago
#
#                          country      continent          state state_code  \
# 970912                    France         Europe  Ile-de-France        IDF
# 970907            United Kingdom         Europe        England        ENG
# 970896            United Kingdom         Europe        England        ENG
# 970895  United States of America  North America       New York         NY
# 970890  United States of America  North America       New York         NY
# ...                          ...            ...            ...        ...
# 176     United States of America  North America        Arizona         AZ
# 173     United States of America  North America       Illinois         IL
# 109     United States of America  North America  Massachusetts         MA
# 75      United States of America  North America       Michigan         MI
# 29      United States of America  North America       Illinois         IL
#
#        tweet_for                                        clean_tweet polarity  \
# 970912     Trump  stop laying   paris and london dont give a fuc...     -0.4
# 970907     Trump  donald trump  mosw    shared by  trump   t  uw...      0.0
# 970896     Trump    trump is being made to embrace defeat via me...     -0.5
# 970895     Trump  have you know decency trump    do you know wha...     -0.6
# 970890     Trump  c mo pas  el abogado de trump de un hotel a un...      0.0
# ...          ...                                                ...      ...
# 176        Trump  bidenharris bidenharris bidenharris bidenharri...      0.0
# 173        Trump  the president  got impeached for something joe...      0.0
# 109        Trump            donaldtrump hunterbiden   t  tbdfpoedzx      0.0
# 75         Trump                           donaldtrump  more years       0.5
# 29         Trump   _jc grab  by the balls  amp  chuck the bastar...      0.0
#
#         subjectivity  sentiment
# 970912           0.6   negative
# 970907           0.0    neutral
# 970896           0.7   negative
# 970895           0.7   negative
# 970890           0.0    neutral
# ...              ...        ...
# 176              0.0    neutral
# 173              0.0    neutral
# 109              0.0    neutral
# 75               0.5   positive
# 29               1.0    neutral
#
# [55498 rows x 21 columns]

# %%
t_pos = len(trump_data_clean.loc[trump_data_clean.sentiment=='positive'])
t_neu = len(trump_data_clean.loc[trump_data_clean.sentiment=='neutral'])
t_neg = len(trump_data_clean.loc[trump_data_clean.sentiment=='negative'])

t_data = {'Positive':t_pos,'Neutral':t_neu,'Negative':t_neg}
t_senti = list(t_data.keys()) 
t_ntweets = list(t_data.values()) 

plt.figure(figsize = (15, 7)) 
plt.bar(t_senti, t_ntweets) 
plt.xlabel("Sentiment") 
plt.ylabel("Number of tweets") 
plt.title("Trump tweets by Sentiment") 
plt.show()

# %%
trump_words = []
words = trump_data_clean['clean_tweet'].str.split().values.tolist()
trump_words = [word for i in words for word in i]

trump_counter = Counter(trump_words)
trump_most = trump_counter.most_common()

# %%
trump_x, trump_y = [], []
for word, count in trump_most[:100]:
    if word not in stop:
        trump_x.append(word)
        trump_y.append(count)

# %%
plt.figure(figsize = (15, 7)) 
plt.bar(trump_x[:15], trump_y[:15],color='red')
plt.xticks(rotation=45)
plt.xlabel("Words") 
plt.ylabel("Count") 
plt.title("Trump tweets top 15 words") 
plt.show()

# %%
word_cloud(trump_data_clean['clean_tweet'][0:1000], 'Trump World Cloud')

# %% [markdown]
# ## Biden

# %%
biden_data_clean = total_data.query('(tweet_for == "Biden")').sort_values('created_at',ascending = False).drop_duplicates(['user_name'])
biden_data_clean['clean_tweet'] = biden_data_clean['tweet'].apply(clean)

# %%
biden_blob = [TextBlob(desc) for desc in biden_data_clean['tweet']]
biden_data_clean['polarity'] = [b.sentiment.polarity for b in biden_blob]
biden_data_clean['subjectivity'] = [b.sentiment.subjectivity for b in biden_blob]
biden_data_clean
# Out:
#                 created_at                                              tweet  \
# 776881 2020-11-08 23:59:38  Stop laying @CNN !\n#Paris and #London dont gi...
# 776876 2020-11-08 23:59:16  Mr. #Biden, tear down that wall (with #Mexico)...
# 737087 2020-11-08 23:58:51  Have you know decency #Trump  @GOP? Do you kno...
# 776869 2020-11-08 23:58:46  No puede ser lo #Panazis como siempre sacando ...
# 776865 2020-11-08 23:58:24  @FLOTUS I’m excited to have a FLOTUS whose vag...
# ...                    ...                                                ...
# 81     2020-10-15 00:05:22                #Biden lied https://t.co/Lqy0TBpXkg
# 53     2020-10-15 00:03:24  This is from the same night I met the cast of ...
# 52     2020-10-15 00:03:23  Hunter #Biden introduced Ukrainian businessman...
# 29     2020-10-15 00:02:06  Come on @ABC PLEASE DO THE RIGHT THING. Move t...
# 25     2020-10-15 00:01:57  @RealJamesWoods #BidenCrimeFamily #JoeBiden #H...
#
#         likes  retweet_count               source       user_id  \
# 776881    0.0            0.0   Twitter for iPhone  3.873620e+08
# 776876    1.0            0.0   Twitter for iPhone  3.772296e+08
# 737087    3.0            0.0      Twitter Web App  4.835231e+07
# 776869    0.0            0.0   Twitter for iPhone  7.406354e+17
# 776865    0.0            0.0   Twitter for iPhone  5.545625e+07
# ...       ...            ...                  ...           ...
# 81        3.0            0.0   Twitter for iPhone  5.052006e+08
# 53        0.0            0.0   Twitter for iPhone  5.581804e+08
# 52        1.0            2.0   Twitter for iPhone  2.964581e+09
# 29        0.0            0.0      Twitter Web App  3.343224e+08
# 25        0.0            0.0  Twitter for Android  1.300837e+18
#
#                                      user_name  user_followers_count  \
# 776881                                 flaquet                  27.0
# 776876                               Tim Welch                 444.0
# 737087  Linda "I Voted for Biden" Kenney Baden                3024.0
# 776869                               JeanCarlo                2313.0
# 776865                      Caroline Billinson                 436.0
# ...                                        ...                   ...
# 81                                  Todd Nelon                 106.0
# 53                  🦩 Hannah for Biden/Harris🦩                 133.0
# 52                          Adam K.Pawłowski🇵🇱                4345.0
# 29                                   Elphygirl                 166.0
# 25                                    Sam KEYS                  29.0
#
#                    user_location        lat        long          city  \
# 776881                     PARIS  48.856697    2.351462         Paris
# 776876              Auckland, NZ -36.852095  174.763180      Auckland
# 737087             New York, USA  40.712728  -74.006015      New York
# 776869  Tijuana, Baja California  32.501019 -116.964663       Tijuana
# 776865            Washington, DC  38.894992  -77.036558    Washington
# ...                          ...        ...         ...           ...
# 81                   Atlanta, GA  33.749099  -84.390185       Atlanta
# 53              Indianapolis, IN  39.768333  -86.158350  Indianapolis
# 52                Poland, Warsaw  52.231958   21.006725        Warsaw
# 29                  New York, NY  40.712728  -74.006015      New York
# 25               Los Angeles, CA  34.053691 -118.242766   Los Angeles
#
#                          country      continent                 state  \
# 776881                    France         Europe         Ile-de-France
# 776876               New Zealand        Oceania              Auckland
# 737087  United States of America  North America              New York
# 776869                    Mexico  North America       Baja California
# 776865  United States of America  North America  District of Columbia
# ...                          ...            ...                   ...
# 81      United States of America  North America               Georgia
# 53      United States of America  North America               Indiana
# 52                        Poland         Europe  Masovian Voivodeship
# 29      United States of America  North America              New York
# 25      United States of America  North America            California
#
#        state_code tweet_for  \
# 776881        IDF     Biden
# 776876        AUK     Biden
# 737087         NY     Biden
# 776869        BCN     Biden
# 776865         DC     Biden
# ...           ...       ...
# 81             GA     Biden
# 53             IN     Biden
# 52             MA     Biden
# 29             NY     Biden
# 25             CA     Biden
#
#                                               clean_tweet  polarity  \
# 776881  stop laying   paris and london dont give a fuc... -0.500000
# 776876  mr  biden  tear down that wall  with mexi   wh...  0.242882
# 737087  have you know decency trump    do you know wha... -0.200000
# 776869  no puede ser lo panazis mo siempre sacando el ... -0.500000
# 776865   i m excited to have a flotus whose vagina i h...  0.375000
# ...                                                   ...       ...
# 81                                       biden lied   t    0.000000
# 53      this is from the same night i met the cast of ...  0.000000
# 52      hunter biden introduced ukrainian businessman ... -0.050446
# 29      me on  please do the right thing  move the bid...  0.078571
# 25       bidencrimefamily joebiden hunterbiden hunterb...  0.000000
#
#         subjectivity
# 776881      0.600000
# 776876      0.530556
# 737087      0.400000
# 776869      0.750000
# 776865      0.750000
# ...              ...
# 81          0.000000
# 53          0.125000
# 52          0.433929
# 29          0.178571
# 25          0.000000
#
# [61891 rows x 20 columns]

# %%
biden_data_clean.loc[biden_data_clean.polarity > 0,'sentiment'] = 'positive'
biden_data_clean.loc[biden_data_clean.polarity == 0,'sentiment'] = 'neutral'
biden_data_clean.loc[biden_data_clean.polarity < 0,'sentiment'] = 'negative'
biden_data_clean
# Out:
#                 created_at                                              tweet  \
# 776881 2020-11-08 23:59:38  Stop laying @CNN !\n#Paris and #London dont gi...
# 776876 2020-11-08 23:59:16  Mr. #Biden, tear down that wall (with #Mexico)...
# 737087 2020-11-08 23:58:51  Have you know decency #Trump  @GOP? Do you kno...
# 776869 2020-11-08 23:58:46  No puede ser lo #Panazis como siempre sacando ...
# 776865 2020-11-08 23:58:24  @FLOTUS I’m excited to have a FLOTUS whose vag...
# ...                    ...                                                ...
# 81     2020-10-15 00:05:22                #Biden lied https://t.co/Lqy0TBpXkg
# 53     2020-10-15 00:03:24  This is from the same night I met the cast of ...
# 52     2020-10-15 00:03:23  Hunter #Biden introduced Ukrainian businessman...
# 29     2020-10-15 00:02:06  Come on @ABC PLEASE DO THE RIGHT THING. Move t...
# 25     2020-10-15 00:01:57  @RealJamesWoods #BidenCrimeFamily #JoeBiden #H...
#
#         likes  retweet_count               source       user_id  \
# 776881    0.0            0.0   Twitter for iPhone  3.873620e+08
# 776876    1.0            0.0   Twitter for iPhone  3.772296e+08
# 737087    3.0            0.0      Twitter Web App  4.835231e+07
# 776869    0.0            0.0   Twitter for iPhone  7.406354e+17
# 776865    0.0            0.0   Twitter for iPhone  5.545625e+07
# ...       ...            ...                  ...           ...
# 81        3.0            0.0   Twitter for iPhone  5.052006e+08
# 53        0.0            0.0   Twitter for iPhone  5.581804e+08
# 52        1.0            2.0   Twitter for iPhone  2.964581e+09
# 29        0.0            0.0      Twitter Web App  3.343224e+08
# 25        0.0            0.0  Twitter for Android  1.300837e+18
#
#                                      user_name  user_followers_count  \
# 776881                                 flaquet                  27.0
# 776876                               Tim Welch                 444.0
# 737087  Linda "I Voted for Biden" Kenney Baden                3024.0
# 776869                               JeanCarlo                2313.0
# 776865                      Caroline Billinson                 436.0
# ...                                        ...                   ...
# 81                                  Todd Nelon                 106.0
# 53                  🦩 Hannah for Biden/Harris🦩                 133.0
# 52                          Adam K.Pawłowski🇵🇱                4345.0
# 29                                   Elphygirl                 166.0
# 25                                    Sam KEYS                  29.0
#
#                    user_location        lat  ...          city  \
# 776881                     PARIS  48.856697  ...         Paris
# 776876              Auckland, NZ -36.852095  ...      Auckland
# 737087             New York, USA  40.712728  ...      New York
# 776869  Tijuana, Baja California  32.501019  ...       Tijuana
# 776865            Washington, DC  38.894992  ...    Washington
# ...                          ...        ...  ...           ...
# 81                   Atlanta, GA  33.749099  ...       Atlanta
# 53              Indianapolis, IN  39.768333  ...  Indianapolis
# 52                Poland, Warsaw  52.231958  ...        Warsaw
# 29                  New York, NY  40.712728  ...      New York
# 25               Los Angeles, CA  34.053691  ...   Los Angeles
#
#                          country      continent                 state  \
# 776881                    France         Europe         Ile-de-France
# 776876               New Zealand        Oceania              Auckland
# 737087  United States of America  North America              New York
# 776869                    Mexico  North America       Baja California
# 776865  United States of America  North America  District of Columbia
# ...                          ...            ...                   ...
# 81      United States of America  North America               Georgia
# 53      United States of America  North America               Indiana
# 52                        Poland         Europe  Masovian Voivodeship
# 29      United States of America  North America              New York
# 25      United States of America  North America            California
#
#        state_code tweet_for  \
# 776881        IDF     Biden
# 776876        AUK     Biden
# 737087         NY     Biden
# 776869        BCN     Biden
# 776865         DC     Biden
# ...           ...       ...
# 81             GA     Biden
# 53             IN     Biden
# 52             MA     Biden
# 29             NY     Biden
# 25             CA     Biden
#
#                                               clean_tweet  polarity  \
# 776881  stop laying   paris and london dont give a fuc... -0.500000
# 776876  mr  biden  tear down that wall  with mexi   wh...  0.242882
# 737087  have you know decency trump    do you know wha... -0.200000
# 776869  no puede ser lo panazis mo siempre sacando el ... -0.500000
# 776865   i m excited to have a flotus whose vagina i h...  0.375000
# ...                                                   ...       ...
# 81                                       biden lied   t    0.000000
# 53      this is from the same night i met the cast of ...  0.000000
# 52      hunter biden introduced ukrainian businessman ... -0.050446
# 29      me on  please do the right thing  move the bid...  0.078571
# 25       bidencrimefamily joebiden hunterbiden hunterb...  0.000000
#
#         subjectivity  sentiment
# 776881      0.600000   negative
# 776876      0.530556   positive
# 737087      0.400000   negative
# 776869      0.750000   negative
# 776865      0.750000   positive
# ...              ...        ...
# 81          0.000000    neutral
# 53          0.125000    neutral
# 52          0.433929   negative
# 29          0.178571   positive
# 25          0.000000    neutral
#
# [61891 rows x 21 columns]

# %%
b_pos = len(biden_data_clean.loc[biden_data_clean.sentiment=='positive'])
b_neu = len(biden_data_clean.loc[biden_data_clean.sentiment=='neutral'])
b_neg = len(biden_data_clean.loc[biden_data_clean.sentiment=='negative'])

b_data = {'Positive':b_pos,'Neutral':b_neu,'Negative':b_neg}
b_senti = list(b_data.keys()) 
b_ntweets = list(b_data.values()) 

plt.figure(figsize = (15, 7)) 
plt.bar(b_senti, b_ntweets) 
plt.xlabel("Sentiment") 
plt.ylabel("Number of tweets") 
plt.title("Biden tweets by Sentiment") 
plt.show()

# %%
biden_words = []
words = biden_data_clean['clean_tweet'].str.split().values.tolist()
biden_words = [word for i in words for word in i]

biden_counter = Counter(biden_words)
biden_most = biden_counter.most_common()

# %%
biden_x, biden_y = [], []
for word, count in biden_most[:100]:
    if word not in stop:
        biden_x.append(word)
        biden_y.append(count)

# %%
plt.figure(figsize = (15, 7)) 
plt.bar(biden_x[:15], biden_y[:15],color='blue')
plt.xticks(rotation=45)
plt.xlabel("Words") 
plt.ylabel("Count") 
plt.title("Biden tweets top 15 words") 
plt.show()

# %%
word_cloud(biden_data_clean['clean_tweet'][0:1000], 'Biden World Cloud')

# %% [markdown]
# ## Both

# %%
total_data_new=pd.concat([trump_data_clean,biden_data_clean])
total_data_new.sort_values(by='created_at')
# Out:
#                 created_at                                              tweet  \
# 29     2020-10-15 00:01:30  @karatblood @KazePlays_JC Grab @realDonaldTrum...
# 25     2020-10-15 00:01:57  @RealJamesWoods #BidenCrimeFamily #JoeBiden #H...
# 29     2020-10-15 00:02:06  Come on @ABC PLEASE DO THE RIGHT THING. Move t...
# 52     2020-10-15 00:03:23  Hunter #Biden introduced Ukrainian businessman...
# 53     2020-10-15 00:03:24  This is from the same night I met the cast of ...
# ...                    ...                                                ...
# 970896 2020-11-08 23:58:54  @TeamTrump @alex281832 #Trump is being made to...
# 776876 2020-11-08 23:59:16  Mr. #Biden, tear down that wall (with #Mexico)...
# 970907 2020-11-08 23:59:25  Donald Trump, Moscow, 1996, shared by @oooroma...
# 776881 2020-11-08 23:59:38  Stop laying @CNN !\n#Paris and #London dont gi...
# 970912 2020-11-08 23:59:38  Stop laying @CNN !\n#Paris and #London dont gi...
#
#         likes  retweet_count               source       user_id  \
# 29        2.0            0.0   Twitter for iPhone  3.602439e+07
# 25        0.0            0.0  Twitter for Android  1.300837e+18
# 29        0.0            0.0      Twitter Web App  3.343224e+08
# 52        1.0            2.0   Twitter for iPhone  2.964581e+09
# 53        0.0            0.0   Twitter for iPhone  5.581804e+08
# ...       ...            ...                  ...           ...
# 970896    1.0            0.0  Twitter for Android  5.008862e+08
# 776876    1.0            0.0   Twitter for iPhone  3.772296e+08
# 970907    8.0            3.0      Twitter Web App  3.881374e+08
# 776881    0.0            0.0   Twitter for iPhone  3.873620e+08
# 970912    0.0            0.0   Twitter for iPhone  3.873620e+08
#
#                          user_name  user_followers_count  \
# 29                          Baylee                1952.0
# 25                        Sam KEYS                  29.0
# 29                       Elphygirl                 166.0
# 52              Adam K.Pawłowski🇵🇱                4345.0
# 53      🦩 Hannah for Biden/Harris🦩                 133.0
# ...                            ...                   ...
# 970896                  Ken Noble😎                 453.0
# 776876                   Tim Welch                 444.0
# 970907       Elisabeth Schimpfössl                 586.0
# 776881                     flaquet                  27.0
# 970912                     flaquet                  27.0
#
#                   user_location        lat  ...          city  \
# 29      Western Washington, USA  41.882823  ...       Chicago
# 25              Los Angeles, CA  34.053691  ...   Los Angeles
# 29                 New York, NY  40.712728  ...      New York
# 52               Poland, Warsaw  52.231958  ...        Warsaw
# 53             Indianapolis, IN  39.768333  ...  Indianapolis
# ...                         ...        ...  ...           ...
# 970896         West London, UK   51.532568  ...        London
# 776876             Auckland, NZ -36.852095  ...      Auckland
# 970907          London, England  51.507322  ...        London
# 776881                    PARIS  48.856697  ...         Paris
# 970912                    PARIS  48.856697  ...         Paris
#
#                          country      continent                 state  \
# 29      United States of America  North America              Illinois
# 25      United States of America  North America            California
# 29      United States of America  North America              New York
# 52                        Poland         Europe  Masovian Voivodeship
# 53      United States of America  North America               Indiana
# ...                          ...            ...                   ...
# 970896            United Kingdom         Europe               England
# 776876               New Zealand        Oceania              Auckland
# 970907            United Kingdom         Europe               England
# 776881                    France         Europe         Ile-de-France
# 970912                    France         Europe         Ile-de-France
#
#        state_code tweet_for  \
# 29             IL     Trump
# 25             CA     Biden
# 29             NY     Biden
# 52             MA     Biden
# 53             IN     Biden
# ...           ...       ...
# 970896        ENG     Trump
# 776876        AUK     Biden
# 970907        ENG     Trump
# 776881        IDF     Biden
# 970912        IDF     Trump
#
#                                               clean_tweet  polarity  \
# 29       _jc grab  by the balls  amp  chuck the bastar...  0.000000
# 25       bidencrimefamily joebiden hunterbiden hunterb...  0.000000
# 29      me on  please do the right thing  move the bid...  0.078571
# 52      hunter biden introduced ukrainian businessman ... -0.050446
# 53      this is from the same night i met the cast of ...  0.000000
# ...                                                   ...       ...
# 970896    trump is being made to embrace defeat via me... -0.500000
# 776876  mr  biden  tear down that wall  with mexi   wh...  0.242882
# 970907  donald trump  mosw    shared by  trump   t  uw...  0.000000
# 776881  stop laying   paris and london dont give a fuc... -0.500000
# 970912  stop laying   paris and london dont give a fuc... -0.400000
#
#         subjectivity  sentiment
# 29          1.000000    neutral
# 25          0.000000    neutral
# 29          0.178571   positive
# 52          0.433929   negative
# 53          0.125000    neutral
# ...              ...        ...
# 970896      0.700000   negative
# 776876      0.530556   positive
# 970907      0.000000    neutral
# 776881      0.600000   negative
# 970912      0.600000   negative
#
# [117389 rows x 21 columns]

# %%
total_data_new.isnull().sum()
# Out:
# created_at              0
# tweet                   0
# likes                   0
# retweet_count           0
# source                  0
# user_id                 0
# user_name               0
# user_followers_count    0
# user_location           0
# lat                     0
# long                    0
# city                    0
# country                 0
# continent               0
# state                   0
# state_code              0
# tweet_for               0
# clean_tweet             0
# polarity                0
# subjectivity            0
# sentiment               0
# dtype: int64

# %%
plt.figure(figsize=(15,9))
bar_plot=sns.countplot(x = 'sentiment', hue = 'tweet_for', data = total_data_new, palette = ['r','b'])
#plt.ylim(0, 20)
#plt.xlim(0, 3)
plt.xticks(rotation=0)
plt.ylabel('Number of Tweets')
plt.title('Trump vs Biden tweets by source')
plt.show()

# %%
plt.subplots(2, 1, figsize=(15, 7))
plt.subplot(1, 2, 1)
general  = trump_data_clean.groupby('sentiment').sentiment.count()
plt.title('Trump -- Sentiment analysis for tweets')
general.plot.pie(autopct="%.1f%%");

plt.subplot(1, 2, 2)
general  = biden_data_clean.groupby('sentiment').sentiment.count()
plt.title('Biden -- Sentiment analysis for tweets')
general.plot.pie(autopct="%.1f%%");

# %% [markdown]
# ### we can see according to the sentiment analysis of tweets
#
# ### Trump got 31.2% positive tweets
#
# ### Biden got 36.4% positive tweets

# %%
trump_data_clean['date'] = pd.to_datetime(trump_data_clean['created_at']).dt.date
biden_data_clean['date'] = pd.to_datetime(biden_data_clean['created_at']).dt.date

# %%
#plt.suptitle('')
plt.figure(figsize = (15, 7)) 
sns.lineplot(data = trump_data_clean.groupby('date')['polarity'].mean(), label = 'Trump', color = 'red')
sns.lineplot(data = biden_data_clean.groupby('date')['polarity'].mean(), label = 'Biden', color = 'blue')
plt.xticks(rotation=90)
plt.title('Polarity change over date (mean)')
plt.ylabel('Polarity')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
t_pos_1 = trump_data_clean[trump_data_clean['polarity'] > 0]
t_neg_1 = trump_data_clean[trump_data_clean['polarity'] < 0]

b_pos_1 = biden_data_clean[biden_data_clean['polarity'] > 0]
b_neg_1 = biden_data_clean[biden_data_clean['polarity'] < 0]

# %%
plt.figure(figsize = (15, 7)) 
sns.lineplot(data = t_pos_1.groupby('date')['polarity'].mean(), label = 'Trump', color = 'red')
sns.lineplot(data = b_pos_1.groupby('date')['polarity'].mean(), label = 'Biden', color = 'blue')
plt.xticks(rotation=90)
plt.title('Positive Polarity change ')
plt.ylabel('Polarity')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
plt.figure(figsize = (15, 7)) 
sns.lineplot(data = t_neg_1.groupby('date')['polarity'].mean(), label = 'Trump', color = 'red')
sns.lineplot(data = b_neg_1.groupby('date')['polarity'].mean(), label = 'Biden', color = 'blue')
plt.xticks(rotation=90)
plt.title('Negative Polarity changing ')
plt.ylabel('Polarity')
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ### We can see that tweets for Biden are more positive through these graphs.

# %% [markdown]
# ## Applying Machine Learning models

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer

X = total_data_new['tweet']
countvector = CountVectorizer(max_features=10000, min_df=2, stop_words='english')
X = countvector.fit_transform(X)
X.toarray()
y = total_data_new['sentiment']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
prediction = model.predict(X_test)
prediction
# Out:
# E:\000_NEU\Sft\Acon3\lib\site-packages\sklearn\linear_model\_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array(['neutral', 'negative', 'positive', ..., 'neutral', 'negative',
#        'positive'], dtype=object)

# %%
from sklearn.metrics import f1_score, confusion_matrix
f1_score(y_test, prediction, average = 'weighted')
# Out:
# 0.8963448187177195

# %%
confusion_matrix(y_test, prediction)
# Out:
# array([[ 2283,   435,   436],
#        [  101, 12034,   292],
#        [  318,   805,  6774]], dtype=int64)

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(X_train.toarray(), y_train)
predictgnb = gnb.predict(X_test.toarray())
predictgnb
# Out:
# array(['neutral', 'negative', 'negative', ..., 'negative', 'negative',
#        'negative'], dtype='<U8')

# %%
f1_score(y_test, predictgnb, average='weighted')
# Out:
# 0.3350872892076549

# %%
confusion_matrix(y_test, predictgnb)
# Out:
# array([[2873,   76,  205],
#        [8653, 3194,  580],
#        [6400,  223, 1274]], dtype=int64)

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn import svm
classifier = svm.LinearSVC(C=0.1)
classifier.fit(X_train, y_train)
predictsvm = classifier.predict(X_test)
predictsvm
# Out:
# E:\000_NEU\Sft\Acon3\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# array(['neutral', 'negative', 'positive', ..., 'neutral', 'negative',
#        'positive'], dtype=object)

# %%
f1_score(y_test, predictsvm, average='weighted')
# Out:
# 0.9015135260785873

# %%
confusion_matrix(y_test, predictsvm)
# Out:
# array([[ 2320,   449,   385],
#        [   83, 12112,   232],
#        [  292,   825,  6780]], dtype=int64)

# %%
# rbf SVM
clf = svm.SVC(kernel='rbf')
clf.fit(X_train, y_train)
predictsvmr = clf.predict(X_test)
predictsvmr
# Out:
# array(['neutral', 'neutral', 'positive', ..., 'neutral', 'negative',
#        'positive'], dtype=object)

# %%
f1_score(y_test, predictsvmr, average='weighted')
# Out:
# 0.8788579441451575

# %%
confusion_matrix(y_test, predictsvmr)
# Out:
# array([[ 1979,   652,   523],
#        [   48, 12118,   261],
#        [  221,  1039,  6637]], dtype=int64)

# %%
# Linear SVM
clf = svm.SVC(kernel='linear', C=1.0)
clf.fit(X_train, y_train)
predictsvmr1 = clf.predict(X_test)
predictsvmr1
# Out:
# array(['neutral', 'negative', 'positive', ..., 'neutral', 'negative',
#        'positive'], dtype=object)

# %%
f1_score(y_test, predictsvmr1, average='weighted')
# Out:
# 0.899154014293509

# %%
confusion_matrix(y_test, predictsvmr1)
# Out:
# array([[ 2385,   351,   418],
#        [  131, 12025,   271],
#        [  428,   737,  6732]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
classif = RandomForestClassifier(n_estimators=200, random_state=0)
classif.fit(X_train, y_train)
predictforest = classif.predict(X_test)
predictforest
# Out:
# array(['neutral', 'positive', 'positive', ..., 'neutral', 'negative',
#        'positive'], dtype=object)

# %%
f1_score(y_test, predictforest, average='weighted')
# Out:
# 0.8604397480803933

# %%
confusion_matrix(y_test, predictforest)
# Out:
# array([[ 1720,   753,   681],
#        [   39, 12066,   322],
#        [  183,  1143,  6571]], dtype=int64)
